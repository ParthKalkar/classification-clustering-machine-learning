jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052686.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052687.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052688.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052689.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052690.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052691.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052692.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052693.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052694.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052695.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052696.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052697.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052698.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052699.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052700.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052701.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052702.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052703.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052704.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052705.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052706.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052707.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052708.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052709.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052710.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052711.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052712.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052713.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052714.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052715.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052716.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052717.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052718.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052719.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052720.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052721.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052722.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052723.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052724.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052725.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052726.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052727.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052728.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052729.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052730.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052731.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052732.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052733.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052734.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052735.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052736.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052737.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052738.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052739.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052740.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052741.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052742.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052743.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052744.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052745.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052746.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052747.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052748.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052749.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052750.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052751.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052752.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052753.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052754.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052755.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052756.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052757.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052758.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052759.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052760.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052761.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052762.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052763.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052764.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052765.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/052766.jpg
# ...
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057187.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057188.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057189.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057190.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057191.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057192.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057193.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057194.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057195.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057196.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057197.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057198.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057199.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057200.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057201.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057202.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057203.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057204.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057205.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057206.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057207.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057208.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057209.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057210.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057211.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057212.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057213.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057214.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057215.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057216.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057217.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057218.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057219.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057220.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057221.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057222.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057223.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057224.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057225.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057226.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057227.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057228.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057229.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057230.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057231.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057232.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057233.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057234.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057235.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057236.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057237.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057238.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057239.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057240.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057241.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057242.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057243.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057244.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057245.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057246.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057247.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057248.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057249.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057250.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057251.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057252.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057253.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057254.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057255.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057256.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057257.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057258.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057259.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057260.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057261.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057262.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057263.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057264.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057265.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057266.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057267.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057268.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057269.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057270.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057271.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057272.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057273.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057274.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057275.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057276.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057277.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057278.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057279.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057280.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057281.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057282.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057283.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057284.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057285.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057286.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057287.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057288.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057289.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057290.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057291.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057292.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057293.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057294.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057295.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057296.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057297.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057298.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057299.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057300.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057301.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057302.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057303.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057304.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057305.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057306.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057307.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057308.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057309.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057310.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057311.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057312.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057313.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057314.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057315.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057316.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057317.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057318.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057319.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057320.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057321.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057322.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057323.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057324.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057325.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057326.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057327.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057328.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057329.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057330.jpg
#   inflating: /content/processed_celeba_small/processed_celeba_small/celeba/New Folder With Items/057331.jpg

# %%
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/processed_celeba_small'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size),
                                   transforms.ToTensor()]) 
    image_dataset = datasets.ImageFolder(data_dir, transform)
    return torch.utils.data.DataLoader(image_dataset, batch_size = batch_size, shuffle=True)

    return None

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# *Next*, we can view some images! You should seen square images of somewhat-centered faces.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    img = np.transpose(img, (1, 2, 0))
    plt.imshow(img.reshape((32,32,3)))

# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for n in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, n+1, xticks=[], yticks=[])
    imshow(images[n])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    # Note, it is not doable with Sklearn scalers.
    # It should be done manually with 2 or 3 lines of code.
    min, max = feature_range
    return x * (max - min) + min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.9686)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        # 3 (convultional layer + batch normalization layer)'s => should be enough
        # Make use of the conv function defined for you above.
        # You should also define a fully-connected layer here.
        # Write 4 or 5 lines here
        self.conv_dim = conv_dim
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # (16, 16, conv_dim)
        self.conv2 = conv(conv_dim, conv_dim*2, 4) # (8, 8, conv_dim*2)
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4) # (4, 4, conv_dim*4)
        self.conv4 = conv(conv_dim*4, conv_dim*8, 4) # (2, 2, conv_dim*8)
        
        self.classifier = nn.Linear(conv_dim*8*2*2, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        # Use the defined conv layers and the fc layer here.
        # Write 4-6 lines here
        lay = F.leaky_relu(self.conv1(x), 0.2)
        lay = F.leaky_relu(self.conv2(lay), 0.2)
        lay = F.leaky_relu(self.conv3(lay), 0.2)
        lay = F.leaky_relu(self.conv4(lay), 0.2)
        
        lay = lay.view(-1, self.conv_dim*8*2*2)
        lay = self.classifier(lay)
        return lay


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# tests.test_discriminator(Discriminator)
# Out:
# "\nDON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE\n"

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # create a sequence of transpose + optional batch norm layers
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        # complete init function
        # 3 (convultional transpose layer + batch normalization layer)'s => should be enough
        # Dont put batch normalization after the last deconv layer.
        # Make use of the deconv function defined for you above.
        # You should also define a fully-connected layer here.
        # This function should be the mirrored functionality of the discriminator.
        # Write 4 or 5 lines here
        self.conv_dim = conv_dim

        self.fc = nn.Linear(z_size, conv_dim*8*2*2)
        
        self.t_conv1 = deconv(conv_dim*8, conv_dim*4, 4)
        self.t_conv2 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv3 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv4 = deconv(conv_dim, 3, 4, batch_norm=False)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        lay = self.fc(x)
        lay = lay.view(-1, self.conv_dim*8, 2, 2) # (batch_size, depth, 4, 4)
        
        lay = F.relu(self.t_conv1(lay))
        lay = F.relu(self.t_conv2(lay))
        lay = F.relu(self.t_conv3(lay))
        
        # last layer: tanh activation instead of relu
        lay = self.t_conv4(lay)
        lay = F.tanh(lay)
        return lay

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Out:
# "\nDON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE\n"

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, we will initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.

# %%
from torch.nn import init

def weights_init_normal(m):
  classname = m.__class__.__name__
  if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1 or classname.find('Conv2d') != -1 or classname.find('ConvTranspose2d') != -1):
    init.normal_(m.weight.data, 0.0, 0.02)        
  if hasattr(m, 'bias') and m.bias is not None:
    init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL.
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images = real_images.cuda()
                
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            z = np.random.uniform(-1, 1, size = (batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size = (batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/   20] | d_loss: 1.3757 | g_loss: 1.6678
# Epoch [    1/   20] | d_loss: 0.5313 | g_loss: 7.2172
# Epoch [    1/   20] | d_loss: 0.5600 | g_loss: 3.1223
# Epoch [    1/   20] | d_loss: 0.8862 | g_loss: 7.4231
# Epoch [    1/   20] | d_loss: 0.6854 | g_loss: 2.5584
# Epoch [    1/   20] | d_loss: 0.6742 | g_loss: 5.0049
# Epoch [    1/   20] | d_loss: 0.6292 | g_loss: 2.1645
# Epoch [    1/   20] | d_loss: 0.6952 | g_loss: 2.8630
# Epoch [    1/   20] | d_loss: 0.8728 | g_loss: 2.4956
# Epoch [    1/   20] | d_loss: 1.2008 | g_loss: 5.4677
# Epoch [    1/   20] | d_loss: 0.6942 | g_loss: 1.9497
# Epoch [    1/   20] | d_loss: 0.7244 | g_loss: 2.8217
# Epoch [    1/   20] | d_loss: 0.8055 | g_loss: 3.6024
# Epoch [    1/   20] | d_loss: 0.7587 | g_loss: 2.2872
# Epoch [    1/   20] | d_loss: 0.9698 | g_loss: 1.3731
# Epoch [    2/   20] | d_loss: 0.6932 | g_loss: 2.4173
# Epoch [    2/   20] | d_loss: 0.6386 | g_loss: 2.3048
# Epoch [    2/   20] | d_loss: 0.6999 | g_loss: 2.2098
# Epoch [    2/   20] | d_loss: 1.1178 | g_loss: 3.1575
# Epoch [    2/   20] | d_loss: 0.7974 | g_loss: 1.4498
# Epoch [    2/   20] | d_loss: 0.7992 | g_loss: 1.7476
# Epoch [    2/   20] | d_loss: 0.8711 | g_loss: 1.2917
# Epoch [    2/   20] | d_loss: 0.7852 | g_loss: 2.2726
# Epoch [    2/   20] | d_loss: 1.3688 | g_loss: 3.1111
# Epoch [    2/   20] | d_loss: 0.8119 | g_loss: 2.4647
# Epoch [    2/   20] | d_loss: 0.6958 | g_loss: 2.2388
# Epoch [    2/   20] | d_loss: 0.8944 | g_loss: 1.1449
# Epoch [    2/   20] | d_loss: 1.0783 | g_loss: 1.9758
# Epoch [    2/   20] | d_loss: 1.1859 | g_loss: 4.1535
# Epoch [    2/   20] | d_loss: 0.7224 | g_loss: 1.7594
# Epoch [    3/   20] | d_loss: 0.8364 | g_loss: 2.4912
# Epoch [    3/   20] | d_loss: 0.9031 | g_loss: 0.9708
# Epoch [    3/   20] | d_loss: 1.0987 | g_loss: 3.3335
# Epoch [    3/   20] | d_loss: 0.6736 | g_loss: 2.0021
# Epoch [    3/   20] | d_loss: 1.0419 | g_loss: 1.0058
# Epoch [    3/   20] | d_loss: 0.8834 | g_loss: 2.3080
# Epoch [    3/   20] | d_loss: 0.7351 | g_loss: 2.6105
# Epoch [    3/   20] | d_loss: 0.9795 | g_loss: 2.3764
# Epoch [    3/   20] | d_loss: 0.8824 | g_loss: 2.2231
# Epoch [    3/   20] | d_loss: 0.7817 | g_loss: 2.0157
# Epoch [    3/   20] | d_loss: 0.7717 | g_loss: 1.2440
